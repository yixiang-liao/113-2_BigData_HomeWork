# %%
import os
import sys
import pandas as pd
import argparse
from datetime import datetime, timedelta
import pathlib

# 新增：將上一層目錄加入 sys.path
parent_path = pathlib.Path().absolute().parent
sys.path.insert(0, str(parent_path))
# Setup Django environment
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'website_configs.settings')
import django
django.setup()
# 重要：設定環境變數以允許在 Jupyter 的異步環境中執行同步操作
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Now we can import Django models
from app_user_keyword_db.models import NewsData
from app_top_person_db.models import TopPerson

# %%
from django.db.models import Q, Max, F
from collections import Counter

# %%
# Searching keywords from "content" column
# This function now uses database queries instead of pandas
def filter_database_fullText(user_keywords, cond, cate, weeks):
    # Get the latest date in the database
    latest_date = NewsData.objects.aggregate(max_date=Max('date'))['max_date']
    
    # Calculate start date
    start_date = latest_date - timedelta(weeks=weeks)
    
    # Base query - filter by date range
    queryset = NewsData.objects.filter(date__gte=start_date, date__lte=latest_date)
    
    # Filter by category if not "全部"
    if cate != "全部":
        queryset = queryset.filter(category=cate)
    
    # Filter by keywords based on condition (AND or OR)
    if cond == 'and':
        # For AND condition, we need all keywords to be present
        for kw in user_keywords:
            queryset = queryset.filter(content__contains=kw)
    elif cond == 'or':
        # For OR condition, any keyword can be present
        q_objects = Q()
        for kw in user_keywords:
            q_objects |= Q(content__contains=kw)
        queryset = queryset.filter(q_objects)
    
    return queryset

# %%
user_keywords = ['烏克蘭', '俄羅斯']  # Example keywords
cond = 'and'  # Example condition (and/or), 
cate = '全部'  # Example category (or "全部" for all categories)
weeks = 4  # Example weeks
queryset = filter_database_fullText(user_keywords, cond, cate, weeks)

# %%
for news in queryset:
    print(news.title)
# Out:
# 俄侵烏克蘭全球憤慨 臉書放寬規定讓人抒發怒火
# Apple新品一次看 iPhone SE售1萬3900元起iPad Air有5色[影]
# 北京冬季帕運閉幕 帕委會主席談和平與希望
# 俄烏談判露曙光 油價下滑5%
# 華碩停止對俄羅斯出貨 捐款3000萬賑濟烏克蘭
# 油價若續漲 朱澤民：今年CPI有可能超過2%
# 澳洲擴大制裁俄羅斯 歐盟要凍結切爾西老闆資產
# 俄羅斯提核協議新要求 伊朗外長將赴莫斯科討論
# 2022酷寒演習展開 3萬北約兵力集結挪威
# 俄國遭制裁降價求售石油和商品 印度考慮採購
# 烏克蘭戰事中國疫情添不安 亞股多數收黑
# 路透社：美中高層已在羅馬會晤
# 借鑑烏克蘭核電廠遭攻 日研議核廠設專屬警備隊
# 烏俄進行第4輪談判 烏克蘭代表稱雙方溝通困難
# 國際博物館協會發聲拒絕戰爭 吳思瑤籲故宮跟進
# 戰爭時文物如何疏散  故宮3個月內擬對策7月推演
# 香港恆指暴跌千點 失守2萬點創6年新低

# %%
# Limit to k results and get specific fields
news_items = queryset.values('category', 'title', 'link', 'photo_link')[:3]

# %%
news_items
# Out:
# <QuerySet [{'category': '科技', 'title': '俄侵烏克蘭全球憤慨 臉書放寬規定讓人抒發怒火', 'link': 'https://www.cna.com.tw/news/ait/202203110088.aspx', 'photo_link': 'https://imgcdn.cna.com.tw/www/WebPhotos/200/20220311/2000x1391_0522240424184.jpg'}, {'category': '科技', 'title': 'Apple新品一次看 iPhone SE售1萬3900元起iPad Air有5色[影]', 'link': 'https://www.cna.com.tw/news/ait/202203090006.aspx', 'photo_link': 'https://imgcdn.cna.com.tw/www/webphotos/WebCover/420/20220309/800x600_644221551345.jpg'}, {'category': '運動', 'title': '北京冬季帕運閉幕 帕委會主席談和平與希望', 'link': 'https://www.cna.com.tw/news/aspt/202203130215.aspx', 'photo_link': None}]>

# %%
dates = list(queryset.values_list('date', flat=True))

# %%
latest_date = NewsData.objects.aggregate(max_date=Max('date'))['max_date']

# Calculate start date
start_date = latest_date - timedelta(weeks=4)  # 4 weeks ago

# %%
category = '政治'  # Example category (or "全部" for all categories)
entities_list = list(NewsData.objects.filter(category=category).filter(date__gte=start_date, date__lte=latest_date).values_list('entities', flat=True))

# %%
entities_list
# Out:
# ["[NerToken(word='烏克蘭', ner='GPE', idx=(4, 7)), NerToken(word='外交部', ner='ORG', idx=(16, 19)), NerToken(word='傍晚', ner='TIME', idx=(24, 26)), NerToken(word='4000', ner='CARDINAL', idx=(32, 36)), NerToken(word='外交部長', ner='ORG', idx=(38, 42)), NerToken(word='吳釗燮', ner='PERSON', idx=(42, 45)), NerToken(word='中午', ner='TIME', idx=(45, 47)), NerToken(word='外交部', ner='ORG', idx=(76, 79)), NerToken(word='晚間', ner='TIME', idx=(79, 81)), NerToken(word='外交部', ner='ORG', idx=(89, 92)), NerToken(word='7日', ner='DATE', idx=(93, 95)), NerToken(word='烏克蘭', ner='NORP', idx=(104, 107)), NerToken(word='外交部', ner='ORG', idx=(122, 125)), NerToken(word='1730', ner='CARDINAL', idx=(133, 137)), NerToken(word='4000', ner='CARDINAL', idx=(152, 156)), NerToken(word='18日', ner='DATE', idx=(195, 198)), NerToken(word='外交部', ner='ORG', idx=(199, 202)), NerToken(word='外交部', ner='ORG', idx=(228, 231)), NerToken(word='吳釗燮', ner='PERSON', idx=(234, 237)), NerToken(word='今天', ner='DATE', idx=(237, 239)), NerToken(word='中午', ner='TIME', idx=(239, 241)), NerToken(word='外交部', ner='ORG', idx=(245, 248)), NerToken(word='吳釗燮', ner='PERSON', idx=(259, 262)), NerToken(word='慈濟', ner='ORG', idx=(266, 268)), NerToken(word='烏克蘭', ner='NORP', idx=(302, 305)), NerToken(word='吳釗燮', ner='PERSON', idx=(321, 324)), NerToken(word='外交部', ner='ORG', idx=(333, 336)), NerToken(word='烏克蘭', ner='NORP', idx=(347, 350)), NerToken(word='外交部', ner='ORG', idx=(367, 370)), NerToken(word='外交部', ner='ORG', idx=(391, 394)), NerToken(word='外交部', ner='ORG', idx=(422, 425)), NerToken(word='6個月', ner='DATE', idx=(449, 452)), NerToken(word='3月18日', ner='DATE', idx=(479, 484)), NerToken(word='下午', ner='TIME', idx=(484, 486)), NerToken(word='5時', ner='TIME', idx=(486, 488)), NerToken(word='20', ner='CARDINAL', idx=(506, 508)), NerToken(word='外交部', ner='ORG', idx=(520, 523)), NerToken(word='外交部', ner='ORG', idx=(524, 527)), NerToken(word='烏克蘭', ner='NORP', idx=(540, 543)), NerToken(word='外交部', ner='ORG', idx=(566, 569))]",
#  "[NerToken(word='今天', ner='DATE', idx=(8, 10)), NerToken(word='2000呎', ner='QUANTITY', idx=(54, 59)), NerToken(word='新竹空軍基地', ner='FAC', idx=(90, 96)), NerToken(word='2000', ner='CARDINAL', idx=(100, 104)), NerToken(word='上午', ner='TIME', idx=(115, 117)), NerToken(word='台東', ner='GPE', idx=(118, 120)), NerToken(word='黃重凱', ner='PERSON', idx=(127, 130)), NerToken(word='柳惠千', ner='PERSON', idx=(216, 219)), NerToken(word='下午', ner='TIME', idx=(222, 224)), NerToken(word='2000呎', ner='QUANTITY', idx=(281, 286)), NerToken(word='2000呎', ner='QUANTITY', idx=(297, 302)), NerToken(word='朱冠甍', ner='PERSON', idx=(453, 456)), NerToken(word='民國109年', ner='DATE', idx=(459, 465)), NerToken(word='許邁德', ner='PERSON', idx=(555, 558)), NerToken(word='英國', ner='GPE', idx=(615, 617)), NerToken(word='美國', ner='GPE', idx=(633, 635)), NerToken(word='許邁德', ner='PERSON', idx=(644, 647)), NerToken(word='1500呎', ner='QUANTITY', idx=(729, 734)), NerToken(word='150浬', ner='QUANTITY', idx=(737, 741))]",
#  "[NerToken(word='今天', ner='DATE', idx=(4, 6)), NerToken(word='法國', ner='GPE', idx=(20, 22)), NerToken(word='今天', ner='DATE', idx=(53, 55)), NerToken(word='新竹空軍基地', ner='FAC', idx=(92, 98)), NerToken(word='上午', ner='TIME', idx=(117, 119)), NerToken(word='台東', ner='GPE', idx=(120, 122)), NerToken(word='黃重凱', ner='PERSON', idx=(131, 134)), NerToken(word='下午', ner='TIME', idx=(191, 193)), NerToken(word='法國', ner='GPE', idx=(212, 214)), NerToken(word='柳惠千', ner='PERSON', idx=(271, 274)), NerToken(word='法國', ner='GPE', idx=(284, 286)), NerToken(word='台', ner='GPE', idx=(295, 296)), NerToken(word='中央社', ner='ORG', idx=(425, 428)), NerToken(word='國防部', ner='ORG', idx=(513, 516)), NerToken(word='國防安全研究院', ner='ORG', idx=(519, 526)), NerToken(word='蘇紫雲', ner='PERSON', idx=(528, 531)), NerToken(word='中央社', ner='ORG', idx=(533, 536)), NerToken(word='法國', ner='GPE', idx=(572, 574))]",
#  "[NerToken(word='行政院長', ner='ORG', idx=(4, 8)), NerToken(word='蘇貞昌', ner='PERSON', idx=(8, 11)), NerToken(word='國民黨', ner='ORG', idx=(12, 15)), NerToken(word='蔣萬安', ner='PERSON', idx=(17, 20)), NerToken(word='立法院長', ner='ORG', idx=(27, 31)), NerToken(word='游錫堃', ner='PERSON', idx=(31, 34)), NerToken(word='今天', ner='DATE', idx=(34, 36)), NerToken(word='中央社', ner='ORG', idx=(42, 45)), NerToken(word='立法院', ner='ORG', idx=(51, 54)), NerToken(word='游錫堃', ner='PERSON', idx=(80, 83)), NerToken(word='蔣萬安', ner='PERSON', idx=(124, 127)), NerToken(word='11日', ner='DATE', idx=(127, 130)), NerToken(word='立法院', ner='ORG', idx=(131, 134)), NerToken(word='蘇貞昌', ner='PERSON', idx=(138, 141)), NerToken(word='蘇貞昌', ner='PERSON', idx=(151, 154)), NerToken(word='蔣經國', ner='PERSON', idx=(163, 166)), NerToken(word='國民黨', ner='ORG', idx=(167, 170)), NerToken(word='大陸', ner='GPE', idx=(177, 179)), NerToken(word='大陸', ner='GPE', idx=(187, 189)), NerToken(word='國民黨', ner='ORG', idx=(220, 223)), NerToken(word='立法院', ner='ORG', idx=(223, 226)), NerToken(word='蘇貞昌', ner='PERSON', idx=(230, 233)), NerToken(word='立法院', ner='ORG', idx=(241, 244)), NerToken(word='游錫堃', ner='PERSON', idx=(258, 261)), NerToken(word='立院', ner='ORG', idx=(283, 285)), NerToken(word='行政院', ner='ORG', idx=(340, 343)), NerToken(word='游錫堃', ner='PERSON', idx=(353, 356)), NerToken(word='今天', ner='DATE', idx=(356, 358)), NerToken(word='中央社', ner='ORG', idx=(364, 367)), NerToken(word='立法院', ner='ORG', idx=(376, 379)), NerToken(word='游錫堃', ner='PERSON', idx=(423, 426)), NerToken(word='立法院', ner='ORG', idx=(429, 432)), NerToken(word='游錫堃', ner='PERSON', idx=(459, 462)), NerToken(word='立法院', ner='ORG', idx=(464, 467)), NerToken(word='行政院', ner='ORG', idx=(468, 471)), NerToken(word='行政院', ner='ORG', idx=(481, 484))]",
#  "[NerToken(word='德國', ner='GPE', idx=(0, 2)), NerToken(word='台', ner='GPE', idx=(3, 4)), NerToken(word='許佑格', ner='PERSON', idx=(8, 11)), NerToken(word='今天', ner='DATE', idx=(11, 13)), NerToken(word='高雄', ner='GPE', idx=(15, 17)), NerToken(word='陳其邁', ner='PERSON', idx=(19, 22)), NerToken(word='高雄市', ner='GPE', idx=(26, 29)), NerToken(word='許佑格', ner='PERSON', idx=(80, 83)), NerToken(word='陳其邁', ner='PERSON', idx=(104, 107)), NerToken(word='台', ner='GPE', idx=(115, 116)), NerToken(word='德', ner='GPE', idx=(117, 118)), NerToken(word='近年', ner='DATE', idx=(118, 120)), NerToken(word='高雄', ner='GPE', idx=(194, 196)), NerToken(word='高雄捷運公司', ner='ORG', idx=(208, 214)), NerToken(word='漢翔航空', ner='ORG', idx=(215, 219)), NerToken(word='西門子公司', ner='ORG', idx=(223, 228)), NerToken(word='陳其邁', ner='PERSON', idx=(258, 261)), NerToken(word='高雄市', ner='GPE', idx=(264, 267)), NerToken(word='德國', ner='GPE', idx=(280, 282)), NerToken(word='台灣', ner='GPE', idx=(320, 322)), NerToken(word='高雄', ner='GPE', idx=(345, 347)), NerToken(word='德國', ner='GPE', idx=(373, 375)), NerToken(word='20年', ner='DATE', idx=(392, 395)), NerToken(word='台', ner='GPE', idx=(398, 399)), NerToken(word='許佑格', ner='PERSON', idx=(400, 403)), NerToken(word='當年', ner='DATE', idx=(410, 412)), NerToken(word='高雄', ner='GPE', idx=(436, 438)), NerToken(word='中央', ner='ORG', idx=(495, 497)), NerToken(word='政府', ner='ORG', idx=(500, 502)), NerToken(word='德商', ner='NORP', idx=(514, 516)), NerToken(word='台灣', ner='GPE', idx=(517, 519)), NerToken(word='許佑格', ner='PERSON', idx=(528, 531)), NerToken(word='南台灣', ner='GPE', idx=(543, 546)), NerToken(word='德商', ner='NORP', idx=(556, 558)), NerToken(word='COVID-19（2019冠狀病毒疾病）疫情', ner='EVENT', idx=(576, 598)), NerToken(word='德國', ner='GPE', idx=(616, 618)), NerToken(word='高雄', ner='GPE', idx=(621, 623))]",
#  "[NerToken(word='台北', ner='GPE', idx=(0, 2)), NerToken(word='柯文哲', ner='PERSON', idx=(4, 7)), NerToken(word='北市府', ner='ORG', idx=(32, 35)), NerToken(word='台北', ner='GPE', idx=(79, 81)), NerToken(word='柯文哲', ner='PERSON', idx=(83, 86)), NerToken(word='君悅酒店', ner='FAC', idx=(87, 91)), NerToken(word='中國', ner='GPE', idx=(92, 94)), NerToken(word='工總', ner='ORG', idx=(108, 110)), NerToken(word='蔡練生', ner='PERSON', idx=(113, 116)), NerToken(word='中國', ner='GPE', idx=(122, 124)), NerToken(word='陳長江', ner='PERSON', idx=(141, 144)), NerToken(word='中國建設銀行台北分行', ner='ORG', idx=(145, 155)), NerToken(word='沈啟明', ner='PERSON', idx=(158, 161)), NerToken(word='交通銀行台北分行', ner='ORG', idx=(162, 170)), NerToken(word='周艷', ner='PERSON', idx=(174, 176)), NerToken(word='中國農業銀行台北辦事處', ner='ORG', idx=(177, 188)), NerToken(word='劉瑞寧', ner='PERSON', idx=(190, 193)), NerToken(word='中國南方航空台北分公司', ner='ORG', idx=(206, 217)), NerToken(word='賴新峰', ner='PERSON', idx=(221, 224)), NerToken(word='中國郵政航空台北分公司', ner='ORG', idx=(225, 236)), NerToken(word='王奕然', ner='PERSON', idx=(239, 242)), NerToken(word='中國東方航空台北分公司', ner='ORG', idx=(243, 254)), NerToken(word='惠楊', ner='PERSON', idx=(258, 260)), NerToken(word='冶春餐廳', ner='ORG', idx=(261, 265)), NerToken(word='申濱', ner='PERSON', idx=(268, 270)), NerToken(word='台灣閩投經濟發展有限公司', ner='ORG', idx=(271, 283)), NerToken(word='李華', ner='PERSON', idx=(288, 290)), NerToken(word='台灣妙管家股份有限公司', ner='ORG', idx=(292, 303)), NerToken(word='李群', ner='PERSON', idx=(306, 308)), NerToken(word='陳智菡', ner='PERSON', idx=(317, 320)), NerToken(word='中央', ner='ORG', idx=(329, 331)), NerToken(word='政府', ner='ORG', idx=(334, 336)), NerToken(word='台灣', ner='GPE', idx=(343, 345)), NerToken(word='台', ner='GPE', idx=(359, 360)), NerToken(word='台灣', ner='GPE', idx=(377, 379)), NerToken(word='北市府', ner='ORG', idx=(384, 387)), NerToken(word='歐商', ner='NORP', idx=(390, 392)), NerToken(word='美商', ner='NORP', idx=(393, 395)), NerToken(word='日商', ner='NORP', idx=(396, 398)), NerToken(word='中商', ner='NORP', idx=(399, 401)), NerToken(word='陳智菡', ner='PERSON', idx=(412, 415)), NerToken(word='柯文哲', ner='PERSON', idx=(420, 423)), NerToken(word='日', ner='GPE', idx=(474, 475)), NerToken(word='中', ner='GPE', idx=(475, 476)), NerToken(word='陳智菡', ner='PERSON', idx=(493, 496)), NerToken(word='今天', ner='DATE', idx=(498, 500)), NerToken(word='一早', ner='TIME', idx=(500, 502)), NerToken(word='工總', ner='ORG', idx=(503, 505)), NerToken(word='工總', ner='ORG', idx=(523, 525)), NerToken(word='北市', ner='GPE', idx=(557, 559)), NerToken(word='蔡練生', ner='PERSON', idx=(576, 579))]",
#  "[NerToken(word='今天', ner='DATE', idx=(2, 4)), NerToken(word='晚上', ner='TIME', idx=(4, 6)), NerToken(word='13', ner='CARDINAL', idx=(13, 15)), NerToken(word='1', ner='CARDINAL', idx=(19, 20)), NerToken(word='5', ner='CARDINAL', idx=(27, 28)), NerToken(word='殲16戰機', ner='PRODUCT', idx=(29, 34)), NerToken(word='7', ner='CARDINAL', idx=(35, 36)), NerToken(word='白天', ner='TIME', idx=(43, 45)), NerToken(word='台灣西南防空識別區', ner='LOC', idx=(47, 56)), NerToken(word='新竹空軍基地', ner='FAC', idx=(90, 96)), NerToken(word='1', ner='CARDINAL', idx=(96, 97)), NerToken(word='2000', ner='CARDINAL', idx=(100, 104)), NerToken(word='2017', ner='PRODUCT', idx=(109, 113)), NerToken(word='上午', ner='TIME', idx=(115, 117)), NerToken(word='台東', ner='GPE', idx=(118, 120)), NerToken(word='黃重凱', ner='PERSON', idx=(129, 132)), NerToken(word='下午', ner='TIME', idx=(171, 173)), NerToken(word='今天', ner='DATE', idx=(176, 178)), NerToken(word='國防部', ner='ORG', idx=(202, 205)), NerToken(word='民國109年9月17日', ner='DATE', idx=(206, 217)), NerToken(word='今天', ner='DATE', idx=(241, 243)), NerToken(word='13', ner='CARDINAL', idx=(245, 247)), NerToken(word='5', ner='CARDINAL', idx=(259, 260)), NerToken(word='殲16戰機', ner='PRODUCT', idx=(261, 266)), NerToken(word='7', ner='CARDINAL', idx=(267, 268)), NerToken(word='殲10戰機', ner='PRODUCT', idx=(269, 274)), NerToken(word='白天', ner='TIME', idx=(275, 277)), NerToken(word='ADIZ', ner='PRODUCT', idx=(289, 293)), NerToken(word='國防部', ner='ORG', idx=(295, 298)), NerToken(word='110年10月1日', ner='DATE', idx=(301, 310)), NerToken(word='38', ner='CARDINAL', idx=(311, 313)), NerToken(word='台', ner='GPE', idx=(318, 319)), NerToken(word='同年10月2日', ner='DATE', idx=(320, 327)), NerToken(word='3', ner='CARDINAL', idx=(327, 328)), NerToken(word='9', ner='CARDINAL', idx=(328, 329)), NerToken(word='10月3日', ner='DATE', idx=(332, 337)), NerToken(word='16', ner='CARDINAL', idx=(337, 339)), NerToken(word='10月4日', ner='DATE', idx=(342, 347)), NerToken(word='5', ner='CARDINAL', idx=(347, 348)), NerToken(word='6', ner='CARDINAL', idx=(348, 349)), NerToken(word='國防部', ner='ORG', idx=(354, 357)), NerToken(word='一', ner='CARDINAL', idx=(373, 374)), NerToken(word='國防部', ner='ORG', idx=(379, 382)), NerToken(word='今年1月23日', ner='DATE', idx=(385, 392)), NerToken(word='39', ner='CARDINAL', idx=(393, 395)), NerToken(word='台', ner='GPE', idx=(400, 401)), NerToken(word='今年', ner='DATE', idx=(403, 405)), NerToken(word='一', ner='CARDINAL', idx=(412, 413))]",
#  "[NerToken(word='雪梨', ner='GPE', idx=(0, 2)), NerToken(word='范惠君', ner='PERSON', idx=(52, 55)), NerToken(word='雪梨僑教中心', ner='ORG', idx=(56, 62)), NerToken(word='施博祥', ner='PERSON', idx=(64, 67)), NerToken(word='雪梨台貿中心', ner='ORG', idx=(68, 74)), NerToken(word='蘇莉莉', ner='PERSON', idx=(76, 79)), NerToken(word='澳洲', ner='GPE', idx=(86, 88)), NerToken(word='雪梨', ner='GPE', idx=(94, 96)), NerToken(word='3月12日', ner='DATE', idx=(98, 103)), NerToken(word='台灣', ner='GPE', idx=(114, 116)), NerToken(word='CPTPP', ner='ORG', idx=(131, 136)), NerToken(word='澳', ner='GPE', idx=(141, 142)), NerToken(word='FTA', ner='ORG', idx=(151, 154)), NerToken(word='澳洲', ner='GPE', idx=(159, 161)), NerToken(word='自由黨國家聯盟', ner='ORG', idx=(163, 170)), NerToken(word='Coalition', ner='ORG', idx=(171, 180)), NerToken(word='澳洲國會', ner='ORG', idx=(187, 191)), NerToken(word='外交、國防及貿易事務聯席委員會', ner='ORG', idx=(192, 207)), NerToken(word='歐布萊恩', ner='PERSON', idx=(311, 315)), NerToken(word='歐布萊恩', ner='PERSON', idx=(339, 343)), NerToken(word='台', ner='GPE', idx=(351, 352)), NerToken(word='澳', ner='GPE', idx=(353, 354)), NerToken(word='歐布萊恩', ner='PERSON', idx=(402, 406)), NerToken(word='澳洲', ner='GPE', idx=(412, 414)), NerToken(word='CPTPP', ner='ORG', idx=(419, 424)), NerToken(word='台', ner='GPE', idx=(444, 445)), NerToken(word='澳', ner='GPE', idx=(446, 447)), NerToken(word='3月10日', ner='DATE', idx=(457, 462)), NerToken(word='工黨（Labor', ner='ORG', idx=(471, 479)), NerToken(word='季欽', ner='PERSON', idx=(483, 485)), NerToken(word='台', ner='GPE', idx=(522, 523)), NerToken(word='季欽', ner='PERSON', idx=(537, 539)), NerToken(word='季欽', ner='PERSON', idx=(555, 557)), NerToken(word='季欽', ner='PERSON', idx=(560, 562)), NerToken(word='台灣', ner='GPE', idx=(568, 570)), NerToken(word='澳洲', ner='GPE', idx=(583, 585)), NerToken(word='台澳', ner='GPE', idx=(621, 623)), NerToken(word='季欽', ner='PERSON', idx=(630, 632)), NerToken(word='范惠君', ner='PERSON', idx=(652, 655)), NerToken(word='季欽', ner='PERSON', idx=(663, 665)), NerToken(word='范惠君', ner='PERSON', idx=(669, 672)), NerToken(word='台灣', ner='GPE', idx=(675, 677)), NerToken(word='2019年9月', ner='DATE', idx=(678, 685)), NerToken(word='CPTPP', ner='ORG', idx=(693, 698)), NerToken(word='范惠君', ner='PERSON', idx=(738, 741)), NerToken(word='2021年6月', ner='DATE', idx=(749, 756)), NerToken(word='澳洲聯邦國會', ner='ORG', idx=(756, 762)), NerToken(word='澳洲台商會', ner='ORG', idx=(781, 786)), NerToken(word='大洋洲商會', ner='ORG', idx=(787, 792)), NerToken(word='澳洲台灣同鄉會', ner='ORG', idx=(793, 800)), NerToken(word='澳台工商委員會', ner='ORG', idx=(801, 808)), NerToken(word='台灣', ner='GPE', idx=(837, 839)), NerToken(word='澳洲國會', ner='ORG', idx=(845, 849)), NerToken(word='30', ner='CARDINAL', idx=(857, 859)), NerToken(word='台灣', ner='GPE', idx=(869, 871)), NerToken(word='澳洲', ner='GPE', idx=(875, 877)), NerToken(word='台灣', ner='GPE', idx=(887, 889)), NerToken(word='台澳', ner='GPE', idx=(899, 901)), NerToken(word='林栢梧', ner='PERSON', idx=(917, 920)), NerToken(word='去年', ner='DATE', idx=(927, 929)), NerToken(word='台灣', ner='GPE', idx=(940, 942)), NerToken(word='葉義深', ner='PERSON', idx=(954, 957)), NerToken(word='雪梨', ner='GPE', idx=(964, 966)), NerToken(word='台灣', ner='GPE', idx=(976, 978)), NerToken(word='澳大利亞', ner='GPE', idx=(993, 997)), NerToken(word='雪梨', ner='GPE', idx=(1020, 1022)), NerToken(word='台灣', ner='GPE', idx=(1033, 1035)), NerToken(word='CPTPP', ner='ORG', idx=(1037, 1042)), NerToken(word='歐布萊恩', ner='PERSON', idx=(1046, 1050)), NerToken(word='季欽', ner='PERSON', idx=(1051, 1053)), NerToken(word='台灣', ner='GPE', idx=(1055, 1057)), NerToken(word='季欽', ner='PERSON', idx=(1060, 1062))]",
#  "[NerToken(word='黃重凱', ner='PERSON', idx=(25, 28)), NerToken(word='傍晚', ner='TIME', idx=(46, 48)), NerToken(word='台東馬偕醫院', ner='FAC', idx=(50, 56)), NerToken(word='黃重凱', ner='PERSON', idx=(78, 81)), NerToken(word='台東馬偕醫院', ner='FAC', idx=(83, 89)), NerToken(word='黃重凱', ner='PERSON', idx=(154, 157)), NerToken(word='下午2時', ner='TIME', idx=(160, 164)), NerToken(word='傍晚', ner='TIME', idx=(171, 173)), NerToken(word='台東馬偕醫院', ner='FAC', idx=(178, 184)), NerToken(word='台東馬偕醫院', ner='FAC', idx=(200, 206)), NerToken(word='蔡福松', ner='PERSON', idx=(208, 211)), NerToken(word='黃重凱', ner='PERSON', idx=(220, 223)), NerToken(word='嘉義', ner='GPE', idx=(227, 229)), NerToken(word='台東', ner='GPE', idx=(231, 233)), NerToken(word='下午', ner='TIME', idx=(267, 269)), NerToken(word='熊厚基', ner='PERSON', idx=(273, 276)), NerToken(word='台東馬偕醫院', ner='FAC', idx=(278, 284)), NerToken(word='知本', ner='GPE', idx=(305, 307)), NerToken(word='台東', ner='GPE', idx=(310, 312)), NerToken(word='海巡署', ner='ORG', idx=(322, 325)), NerToken(word='晚上6時', ner='TIME', idx=(338, 342)), NerToken(word='2021年', ner='DATE', idx=(376, 381)), NerToken(word='新竹', ner='GPE', idx=(407, 409)), NerToken(word='台東志航基地', ner='FAC', idx=(430, 436)), NerToken(word='11時26分', ner='TIME', idx=(465, 471)), NerToken(word='志航基地', ner='FAC', idx=(474, 478)), NerToken(word='10浬', ner='QUANTITY', idx=(480, 483)), NerToken(word='黑鷹', ner='ORG', idx=(504, 506)), NerToken(word='12時6分', ner='TIME', idx=(515, 520))]",
#  "[NerToken(word='1', ner='CARDINAL', idx=(0, 1)), NerToken(word='2000', ner='CARDINAL', idx=(4, 8)), NerToken(word='台東', ner='GPE', idx=(10, 12)), NerToken(word='黃重凱', ner='PERSON', idx=(19, 22)), NerToken(word='黃重凱', ner='PERSON', idx=(27, 30)), NerToken(word='侯富議', ner='PERSON', idx=(35, 38)), NerToken(word='黃重凱', ner='PERSON', idx=(54, 57)), NerToken(word='國立嘉義高中', ner='ORG', idx=(80, 86)), NerToken(word='陳元泰', ner='PERSON', idx=(88, 91)), NerToken(word='今天', ner='DATE', idx=(91, 93)), NerToken(word='黃重凱', ner='PERSON', idx=(95, 98)), NerToken(word='侯富議', ner='PERSON', idx=(101, 104)), NerToken(word='黃重凱', ner='PERSON', idx=(107, 110)), NerToken(word='侯富議', ner='PERSON', idx=(111, 114)), NerToken(word='嘉中', ner='ORG', idx=(115, 117)), NerToken(word='第1', ner='ORDINAL', idx=(117, 119)), NerToken(word='侯富議', ner='PERSON', idx=(130, 133)), NerToken(word='黃重凱', ner='PERSON', idx=(139, 142)), NerToken(word='黃重凱', ner='PERSON', idx=(158, 161)), NerToken(word='今天', ner='DATE', idx=(167, 169)), NerToken(word='侯富議', ner='PERSON', idx=(197, 200)), NerToken(word='侯富議', ner='PERSON', idx=(206, 209)), NerToken(word='黃重凱', ner='PERSON', idx=(212, 215)), NerToken(word='英文', ner='LANGUAGE', idx=(238, 240)), NerToken(word='黃重凱', ner='PERSON', idx=(260, 263)), NerToken(word='2', ner='CARDINAL', idx=(266, 267)), NerToken(word='黃重凱', ner='PERSON', idx=(303, 306)), NerToken(word='嘉義市北興國中', ner='ORG', idx=(308, 315)), NerToken(word='張仁澤', ner='PERSON', idx=(328, 331)), NerToken(word='黃重凱', ner='PERSON', idx=(334, 337)), NerToken(word='黃重凱', ner='PERSON', idx=(348, 351)), NerToken(word='3年', ner='DATE', idx=(353, 355)), NerToken(word='90', ner='CARDINAL', idx=(361, 363)), NerToken(word='語大', ner='ORG', idx=(384, 386)), NerToken(word='1', ner='CARDINAL', idx=(403, 404)), NerToken(word='2000', ner='CARDINAL', idx=(407, 411)), NerToken(word='上午', ner='TIME', idx=(415, 417)), NerToken(word='台東', ner='GPE', idx=(428, 430)), NerToken(word='黃重凱', ner='PERSON', idx=(439, 442)), NerToken(word='台東馬偕醫院', ner='ORG', idx=(453, 459))]",
#  "[NerToken(word='今天', ner='DATE', idx=(4, 6)), NerToken(word='台東', ner='GPE', idx=(7, 9)), NerToken(word='柳惠千', ner='PERSON', idx=(28, 31)), NerToken(word='下午', ner='TIME', idx=(33, 35)), NerToken(word='今天', ner='DATE', idx=(38, 40)), NerToken(word='新竹空軍基地', ner='FAC', idx=(93, 99)), NerToken(word='2000', ner='CARDINAL', idx=(103, 107)), NerToken(word='上午', ner='TIME', idx=(118, 120)), NerToken(word='台東', ner='GPE', idx=(121, 123)), NerToken(word='黃重凱', ner='PERSON', idx=(132, 135)), NerToken(word='下午', ner='TIME', idx=(158, 160)), NerToken(word='柳惠千', ner='PERSON', idx=(166, 169)), NerToken(word='柳惠千', ner='PERSON', idx=(287, 290)), NerToken(word='2000呎', ner='QUANTITY', idx=(341, 346)), NerToken(word='2000呎', ner='QUANTITY', idx=(357, 362)), NerToken(word='柳惠千', ner='PERSON', idx=(390, 393)), NerToken(word='今天', ner='DATE', idx=(396, 398)), NerToken(word='10公尺', ner='QUANTITY', idx=(452, 456)), NerToken(word='5.09公尺', ner='QUANTITY', idx=(459, 465)), NerToken(word='2馬赫', ner='QUANTITY', idx=(472, 475)), NerToken(word='3889公里', ner='QUANTITY', idx=(480, 486)), NerToken(word='1992年', ner='DATE', idx=(487, 492)), NerToken(word='美國', ner='GPE', idx=(493, 495)), NerToken(word='7年', ner='DATE', idx=(515, 517)), NerToken(word='4月', ner='DATE', idx=(517, 519)), NerToken(word='GBU-10', ner='PRODUCT', idx=(577, 583)), NerToken(word='GBU-12', ner='PRODUCT', idx=(584, 590)), NerToken(word='Mk 82', ner='PRODUCT', idx=(597, 602)), NerToken(word='柳惠千', ner='PERSON', idx=(679, 682)), NerToken(word='台灣', ner='GPE', idx=(744, 746)), NerToken(word='柳惠千', ner='PERSON', idx=(753, 756)), NerToken(word='F-16', ner='PRODUCT', idx=(808, 812)), NerToken(word='柳惠千', ner='PERSON', idx=(834, 837)), NerToken(word='上午', ner='TIME', idx=(845, 847)), NerToken(word='10時8分', ner='TIME', idx=(847, 852)), NerToken(word='台東志航基地', ner='FAC', idx=(853, 859)), NerToken(word='11時5分', ner='TIME', idx=(870, 875)), NerToken(word='11時26分', ner='TIME', idx=(890, 896)), NerToken(word='志航基地', ner='FAC', idx=(897, 901)), NerToken(word='10浬', ner='QUANTITY', idx=(903, 906)), NerToken(word='11時53分', ner='TIME', idx=(925, 931)), NerToken(word='11時56分', ner='TIME', idx=(939, 945)), NerToken(word='12時6分', ner='TIME', idx=(952, 957)), NerToken(word='12時13分', ner='TIME', idx=(962, 968)), NerToken(word='志航基地', ner='FAC', idx=(970, 974)), NerToken(word='12時18分', ner='TIME', idx=(975, 981)), NerToken(word='馬偕醫院', ner='ORG', idx=(983, 987)), NerToken(word='柳惠千', ner='PERSON', idx=(990, 993)), NerToken(word='今天', ner='DATE', idx=(996, 998)), NerToken(word='上午', ner='TIME', idx=(998, 1000)), NerToken(word='10至12時', ner='TIME', idx=(1000, 1006)), NerToken(word='2至5海浬', ner='QUANTITY', idx=(1015, 1020)), NerToken(word='4000公尺', ner='QUANTITY', idx=(1024, 1030)), NerToken(word='2000呎', ner='QUANTITY', idx=(1031, 1036)), NerToken(word='87年2月26日', ner='DATE', idx=(1069, 1077)), NerToken(word='去年9月29日', ner='DATE', idx=(1085, 1092)), NerToken(word='黃重凱', ner='PERSON', idx=(1106, 1109)), NerToken(word='95年', ner='DATE', idx=(1114, 1117)), NerToken(word='1434小時', ner='TIME', idx=(1124, 1130)), NerToken(word='1125小時', ner='TIME', idx=(1135, 1141)), NerToken(word='新竹市', ner='GPE', idx=(1144, 1147)), NerToken(word='2', ner='CARDINAL', idx=(1153, 1154)), NerToken(word='柳惠千', ner='PERSON', idx=(1175, 1178)), NerToken(word='今天', ner='DATE', idx=(1181, 1183))]",
#  "[NerToken(word='今天', ner='DATE', idx=(9, 11)), NerToken(word='烏克蘭', ner='GPE', idx=(16, 19)), NerToken(word='今天', ner='DATE', idx=(24, 26)), NerToken(word='下午4時10分', ner='TIME', idx=(26, 33)), NerToken(word='新台幣6億元', ner='MONEY', idx=(43, 49)), NerToken(word='3萬5703美元', ner='MONEY', idx=(65, 73)), NerToken(word='約101萬元', ner='MONEY', idx=(79, 85)), NerToken(word='俄烏', ner='GPE', idx=(89, 91)), NerToken(word='烏克蘭', ner='NORP', idx=(99, 102)), NerToken(word='外交部', ner='ORG', idx=(105, 108)), NerToken(word='2日', ner='DATE', idx=(108, 110)), NerToken(word='烏克蘭', ner='GPE', idx=(123, 126)), NerToken(word='4月1日', ner='DATE', idx=(131, 135)), NerToken(word='4月1日中午12時', ner='TIME', idx=(155, 164)), NerToken(word='晚間', ner='TIME', idx=(185, 187)), NerToken(word='11時59分', ner='TIME', idx=(187, 193)), NerToken(word='今天', ner='DATE', idx=(209, 211)), NerToken(word='3萬5703', ner='MONEY', idx=(215, 221)), NerToken(word='新台幣約101萬元', ner='MONEY', idx=(226, 235)), NerToken(word='紐約台灣商會', ner='ORG', idx=(239, 245)), NerToken(word='紐約台灣商會', ner='ORG', idx=(291, 297)), NerToken(word='1976年', ner='DATE', idx=(300, 305)), NerToken(word='北美', ner='LOC', idx=(307, 309)), NerToken(word='台灣', ner='GPE', idx=(334, 336)), NerToken(word='烏克蘭', ner='NORP', idx=(345, 348)), NerToken(word='4億7222萬元', ner='MONEY', idx=(386, 394)), NerToken(word='1億3788萬元', ner='MONEY', idx=(410, 418)), NerToken(word='10萬', ner='CARDINAL', idx=(438, 441)), NerToken(word='5%', ner='PERCENT', idx=(455, 457)), NerToken(word='45%', ner='PERCENT', idx=(467, 470)), NerToken(word='外交部', ner='ORG', idx=(492, 495)), NerToken(word='波蘭政府', ner='ORG', idx=(502, 506)), NerToken(word='濟烏克蘭難民專責單位', ner='ORG', idx=(510, 520)), NerToken(word='基金會', ner='ORG', idx=(521, 524))]",
#  "[NerToken(word='台南空軍基地', ner='FAC', idx=(0, 6)), NerToken(word='1', ner='CARDINAL', idx=(6, 7)), NerToken(word='今天', ner='DATE', idx=(19, 21)), NerToken(word='中午', ner='TIME', idx=(21, 23)), NerToken(word='2', ner='CARDINAL', idx=(63, 64)), NerToken(word='台南空軍基地', ner='ORG', idx=(72, 78)), NerToken(word='中央社', ner='ORG', idx=(85, 88)), NerToken(word='今天', ner='DATE', idx=(91, 93)), NerToken(word='11時57分', ner='TIME', idx=(95, 101)), NerToken(word='1', ner='CARDINAL', idx=(104, 105)), NerToken(word='空軍司令部', ner='ORG', idx=(164, 169))]",
#  "[NerToken(word='2000', ner='CARDINAL', idx=(8, 12)), NerToken(word='今天', ner='DATE', idx=(14, 16)), NerToken(word='上午', ner='TIME', idx=(16, 18)), NerToken(word='黃重凱平', ner='PERSON', idx=(30, 34)), NerToken(word='柳惠千', ner='PERSON', idx=(50, 53)), NerToken(word='下午', ner='TIME', idx=(55, 57)), NerToken(word='新竹基地', ner='FAC', idx=(93, 97)), NerToken(word='2000', ner='CARDINAL', idx=(106, 110)), NerToken(word='上午10時8分', ner='TIME', idx=(113, 120)), NerToken(word='台東志航基地', ner='FAC', idx=(121, 127)), NerToken(word='11時26分', ner='TIME', idx=(150, 156)), NerToken(word='台東志航基地', ner='FAC', idx=(157, 163)), NerToken(word='10浬', ner='QUANTITY', idx=(165, 168)), NerToken(word='12時6分', ner='TIME', idx=(196, 201)), NerToken(word='下午', ner='TIME', idx=(226, 228)), NerToken(word='柳惠千', ner='PERSON', idx=(234, 237))]",
#  "[NerToken(word='監察院', ner='ORG', idx=(0, 3)), NerToken(word='今天', ner='DATE', idx=(3, 5)), NerToken(word='喬建中', ner='PERSON', idx=(15, 18)), NerToken(word='玉山國家公園', ner='FAC', idx=(22, 28)), NerToken(word='監察院', ner='ORG', idx=(63, 66)), NerToken(word='監察院', ner='ORG', idx=(82, 85)), NerToken(word='喬建中', ner='PERSON', idx=(112, 115)), NerToken(word='民國110年5月15、16日', ner='DATE', idx=(116, 130)), NerToken(word='玉山國家公園', ner='FAC', idx=(134, 140)), NerToken(word='12天', ner='DATE', idx=(166, 169)), NerToken(word='80公頃', ner='QUANTITY', idx=(171, 175)), NerToken(word='葉宜津', ner='PERSON', idx=(190, 193)), NerToken(word='蔡崇義', ner='PERSON', idx=(194, 197)), NerToken(word='賴鼎銘', ner='PERSON', idx=(198, 201)), NerToken(word='喬建中', ner='PERSON', idx=(211, 214)), NerToken(word='監察院', ner='ORG', idx=(346, 349)), NerToken(word='今天', ner='DATE', idx=(354, 356)), NerToken(word='喬建中', ner='PERSON', idx=(384, 387)), NerToken(word='3', ner='CARDINAL', idx=(459, 460)), NerToken(word='1.5公里', ner='QUANTITY', idx=(482, 487)), NerToken(word='監察院', ner='ORG', idx=(523, 526)), NerToken(word='喬建中', ner='PERSON', idx=(529, 532)), NerToken(word='當天', ner='DATE', idx=(535, 537)), NerToken(word='5月', ner='DATE', idx=(564, 566)), NerToken(word='凌晨2時', ner='TIME', idx=(569, 573)), NerToken(word='監察院', ner='ORG', idx=(688, 691)), NerToken(word='喬建中', ner='PERSON', idx=(694, 697)), NerToken(word='108年6月到110年6月', ner='DATE', idx=(698, 711)), NerToken(word='玉山國家公園管理處', ner='ORG', idx=(718, 727)), NerToken(word='12', ner='CARDINAL', idx=(729, 731)), NerToken(word='11', ner='CARDINAL', idx=(739, 741)), NerToken(word='105年7月到110年7月', ner='DATE', idx=(751, 764)), NerToken(word='5年', ner='DATE', idx=(765, 767)), NerToken(word='警政署', ner='ORG', idx=(771, 774)), NerToken(word='41', ner='CARDINAL', idx=(776, 778)), NerToken(word='110年4月', ner='DATE', idx=(784, 790)), NerToken(word='行政院', ner='ORG', idx=(796, 799)), NerToken(word='玉山', ner='GPE', idx=(805, 807)), NerToken(word='喬建中', ner='PERSON', idx=(829, 832)), NerToken(word='監察院', ner='ORG', idx=(844, 847)), NerToken(word='喬建中', ner='PERSON', idx=(850, 853)), NerToken(word='台灣', ner='GPE', idx=(863, 865)), NerToken(word='12天', ner='DATE', idx=(902, 905)), NerToken(word='80公頃', ner='QUANTITY', idx=(907, 911)), NerToken(word='監委', ner='ORG', idx=(924, 926)), NerToken(word='喬建中', ner='PERSON', idx=(931, 934)), NerToken(word='109年10月3日', ner='DATE', idx=(936, 945)), NerToken(word='第206', ner='ORDINAL', idx=(951, 955)), NerToken(word='林務局南投林區管理處', ner='ORG', idx=(965, 975)), NerToken(word='登山社', ner='ORG', idx=(987, 990)), NerToken(word='喬建中', ner='PERSON', idx=(998, 1001)), NerToken(word='102年到109年', ner='DATE', idx=(1003, 1012)), NerToken(word='屯稜線', ner='LOC', idx=(1034, 1037)), NerToken(word='丹大溪', ner='LOC', idx=(1040, 1043)), NerToken(word='巒大溪', ner='LOC', idx=(1044, 1047)), NerToken(word='郡大溪', ner='LOC', idx=(1048, 1051)), NerToken(word='監察院', ner='ORG', idx=(1059, 1062)), NerToken(word='喬建中', ner='PERSON', idx=(1080, 1083)), NerToken(word='監察院', ner='ORG', idx=(1098, 1101)), NerToken(word='喬建中', ner='PERSON', idx=(1104, 1107))]",
#  "[NerToken(word='許舒博', ner='PERSON', idx=(9, 12)), NerToken(word='今天', ner='DATE', idx=(12, 14)), NerToken(word='一', ner='CARDINAL', idx=(16, 17)), NerToken(word='蔡', ner='PERSON', idx=(33, 34)), NerToken(word='5月', ner='DATE', idx=(46, 48)), NerToken(word='蔡', ner='PERSON', idx=(63, 64)), NerToken(word='行政院', ner='ORG', idx=(77, 80)), NerToken(word='沈榮津', ner='PERSON', idx=(83, 86)), NerToken(word='蘇貞昌', ner='PERSON', idx=(95, 98)), NerToken(word='王文淵', ner='PERSON', idx=(115, 118)), NerToken(word='許舒博', ner='PERSON', idx=(130, 133)), NerToken(word='今天', ner='DATE', idx=(210, 212)), NerToken(word='第四', ner='ORDINAL', idx=(215, 217)), NerToken(word='許舒博', ner='PERSON', idx=(253, 256)), NerToken(word='台灣', ner='GPE', idx=(286, 288)), NerToken(word='許舒博', ner='PERSON', idx=(328, 331)), NerToken(word='台灣', ner='GPE', idx=(371, 373)), NerToken(word='台灣', ner='GPE', idx=(388, 390)), NerToken(word='夏季', ner='DATE', idx=(404, 406)), NerToken(word='許舒博', ner='PERSON', idx=(425, 428)), NerToken(word='許舒博', ner='PERSON', idx=(535, 538)), NerToken(word='日前', ner='DATE', idx=(544, 546)), NerToken(word='蔡', ner='PERSON', idx=(547, 548)), NerToken(word='十天', ner='DATE', idx=(585, 587)), NerToken(word='許舒博', ner='PERSON', idx=(596, 599)), NerToken(word='台灣', ner='GPE', idx=(605, 607)), NerToken(word='台灣', ner='GPE', idx=(615, 617)), NerToken(word='台灣', ner='GPE', idx=(631, 633))]",
#  "[NerToken(word='一', ner='CARDINAL', idx=(2, 3)), NerToken(word='2000', ner='PRODUCT', idx=(8, 12)), NerToken(word='今天', ner='DATE', idx=(14, 16)), NerToken(word='上午', ner='TIME', idx=(16, 18)), NerToken(word='黃重凱', ner='PERSON', idx=(28, 31)), NerToken(word='空軍', ner='ORG', idx=(54, 56)), NerToken(word='空軍司令部', ner='ORG', idx=(86, 91)), NerToken(word='新竹基地', ner='FAC', idx=(99, 103)), NerToken(word='一', ner='CARDINAL', idx=(103, 104)), NerToken(word='2017', ner='CARDINAL', idx=(107, 111)), NerToken(word='2000', ner='PRODUCT', idx=(114, 118)), NerToken(word='上午10時8分', ner='TIME', idx=(121, 128)), NerToken(word='台東志航基地', ner='FAC', idx=(129, 135)), NerToken(word='11時26分', ner='TIME', idx=(164, 170)), NerToken(word='台東志航基地', ner='FAC', idx=(171, 177)), NerToken(word='10浬', ner='QUANTITY', idx=(179, 182)), NerToken(word='12時6分', ner='TIME', idx=(212, 217)), NerToken(word='空軍第七聯隊', ner='ORG', idx=(249, 255)), NerToken(word='黃鼎翔', ner='PERSON', idx=(259, 262)), NerToken(word='空軍', ner='ORG', idx=(288, 290)), NerToken(word='下午', ner='TIME', idx=(290, 292)), NerToken(word='七聯隊', ner='ORG', idx=(304, 307)), NerToken(word='黃鼎翔', ner='PERSON', idx=(307, 310)), NerToken(word='黃', ner='PERSON', idx=(328, 329)), NerToken(word='黃鼎翔', ner='PERSON', idx=(359, 362)), NerToken(word='空軍', ner='ORG', idx=(386, 388))]",
#  "[NerToken(word='徐國勇', ner='PERSON', idx=(22, 25)), NerToken(word='今天', ner='DATE', idx=(25, 27)), NerToken(word='立法院', ner='ORG', idx=(29, 32)), NerToken(word='內政部', ner='ORG', idx=(56, 59)), NerToken(word='行政院', ner='ORG', idx=(86, 89)), NerToken(word='去年1月', ner='DATE', idx=(91, 95)), NerToken(word='立法院', ner='ORG', idx=(129, 132)), NerToken(word='今天', ner='DATE', idx=(137, 139)), NerToken(word='徐國勇', ner='PERSON', idx=(141, 144)), NerToken(word='國民黨', ner='ORG', idx=(157, 160)), NerToken(word='洪孟楷', ner='PERSON', idx=(162, 165)), NerToken(word='徐國勇', ner='PERSON', idx=(215, 218)), NerToken(word='行政院', ner='ORG', idx=(230, 233)), NerToken(word='內政部', ner='ORG', idx=(236, 239)), NerToken(word='行政院', ner='ORG', idx=(258, 261)), NerToken(word='沈榮津', ner='PERSON', idx=(264, 267)), NerToken(word='6', ner='CARDINAL', idx=(272, 273)), NerToken(word='過年前', ner='DATE', idx=(281, 284)), NerToken(word='徐國勇', ner='PERSON', idx=(285, 288)), NerToken(word='立法院', ner='ORG', idx=(291, 294)), NerToken(word='內政部', ner='ORG', idx=(314, 317)), NerToken(word='內政部', ner='ORG', idx=(325, 328)), NerToken(word='立法院', ner='ORG', idx=(354, 357)), NerToken(word='內政部', ner='ORG', idx=(358, 361)), NerToken(word='立法院', ner='ORG', idx=(371, 374)), NerToken(word='徐國勇', ner='PERSON', idx=(377, 380)), NerToken(word='立法院', ner='ORG', idx=(415, 418))]",
#  "[NerToken(word='2000', ner='PRODUCT', idx=(8, 12)), NerToken(word='今天', ner='DATE', idx=(14, 16)), NerToken(word='上午', ner='TIME', idx=(16, 18)), NerToken(word='台東', ner='GPE', idx=(19, 21)), NerToken(word='黃重凱', ner='PERSON', idx=(30, 33)), NerToken(word='1997年', ner='DATE', idx=(45, 50)), NerToken(word='第8', ner='ORDINAL', idx=(60, 62)), NerToken(word='7', ner='CARDINAL', idx=(67, 68)), NerToken(word='5', ner='CARDINAL', idx=(72, 73)), NerToken(word='6', ner='CARDINAL', idx=(81, 82)), NerToken(word='54', ner='CARDINAL', idx=(86, 88)), NerToken(word='新竹基地', ner='FAC', idx=(103, 107)), NerToken(word='一', ner='CARDINAL', idx=(107, 108)), NerToken(word='上午10時8分', ner='TIME', idx=(121, 128)), NerToken(word='台東志航基地', ner='FAC', idx=(129, 135)), NerToken(word='11時26分', ner='TIME', idx=(164, 170)), NerToken(word='台東志航基地', ner='FAC', idx=(171, 177)), NerToken(word='10浬', ner='QUANTITY', idx=(179, 182)), NerToken(word='12時6分', ner='TIME', idx=(214, 219)), NerToken(word='法國達梭公司', ner='ORG', idx=(251, 257)), NerToken(word='1997年5月', ner='DATE', idx=(283, 290)), NerToken(word='同年12月', ner='DATE', idx=(301, 306)), NerToken(word='1998年11月', ner='DATE', idx=(319, 327)), NerToken(word='第60', ner='ORDINAL', idx=(329, 332)), NerToken(word='2001年5月10日', ner='DATE', idx=(353, 363)), NerToken(word='今天', ner='DATE', idx=(372, 374)), NerToken(word='8', ner='CARDINAL', idx=(379, 380)), NerToken(word='7', ner='CARDINAL', idx=(389, 390)), NerToken(word='5', ner='CARDINAL', idx=(394, 395)), NerToken(word='法國', ner='GPE', idx=(401, 403)), NerToken(word='王同義', ner='PERSON', idx=(409, 412)), NerToken(word='6', ner='CARDINAL', idx=(418, 419)), NerToken(word='54', ner='CARDINAL', idx=(423, 425)), NerToken(word='第一', ner='ORDINAL', idx=(427, 429)), NerToken(word='1999年10月', ner='DATE', idx=(439, 447)), NerToken(word='新竹', ner='GPE', idx=(490, 492)), NerToken(word='吳彬福', ner='PERSON', idx=(498, 501)), NerToken(word='吳世峰', ner='PERSON', idx=(502, 505)), NerToken(word='第二', ner='ORDINAL', idx=(510, 512)), NerToken(word='同年12月', ner='DATE', idx=(514, 519)), NerToken(word='2036', ner='CARDINAL', idx=(522, 526)), NerToken(word='蘇澳', ner='GPE', idx=(530, 532)), NerToken(word='江金亮', ner='PERSON', idx=(557, 560)), NerToken(word='六個月', ner='DATE', idx=(565, 568)), NerToken(word='第三', ner='ORDINAL', idx=(577, 579)), NerToken(word='2001年11月', ner='DATE', idx=(581, 589)), NerToken(word='2058', ner='PRODUCT', idx=(592, 596)), NerToken(word='新竹基地', ner='FAC', idx=(600, 604)), NerToken(word='新竹', ner='GPE', idx=(621, 623)), NerToken(word='劉浩帆', ner='PERSON', idx=(630, 633)), NerToken(word='張健翔', ner='PERSON', idx=(634, 637)), NerToken(word='第四', ner='ORDINAL', idx=(640, 642)), NerToken(word='2002年11月', ner='DATE', idx=(644, 652)), NerToken(word='何威克', ner='PERSON', idx=(665, 668)), NerToken(word='虞德忠', ner='PERSON', idx=(669, 672)), NerToken(word='第五', ner='ORDINAL', idx=(741, 743)), NerToken(word='2013年5月', ner='DATE', idx=(745, 752)), NerToken(word='劉永祥', ner='PERSON', idx=(778, 781)), NerToken(word='鄭育騰', ner='PERSON', idx=(782, 785)), NerToken(word='第六', ner='ORDINAL', idx=(792, 794)), NerToken(word='2017年11月', ner='DATE', idx=(796, 804)), NerToken(word='基隆市', ner='GPE', idx=(815, 818)), NerToken(word='90浬', ner='QUANTITY', idx=(821, 824)), NerToken(word='何子雨', ner='PERSON', idx=(831, 834)), NerToken(word='王同義', ner='PERSON', idx=(854, 857)), NerToken(word='2010年9月', ner='DATE', idx=(857, 864)), NerToken(word='法國', ner='GPE', idx=(865, 867)), NerToken(word='2年', ner='DATE', idx=(871, 873)), NerToken(word='2012年10月', ner='DATE', idx=(880, 888)), NerToken(word='法國', ner='GPE', idx=(891, 893)), NerToken(word='法國', ner='GPE', idx=(901, 903)), NerToken(word='盧賽基地', ner='FAC', idx=(903, 907)), NerToken(word='王同義', ner='PERSON', idx=(934, 937)), NerToken(word='500公尺', ner='QUANTITY', idx=(951, 956)), NerToken(word='法方', ner='NORP', idx=(965, 967))]",
#  "[NerToken(word='烏克蘭', ner='GPE', idx=(0, 3)), NerToken(word='台灣', ner='GPE', idx=(6, 8)), NerToken(word='4個月', ner='DATE', idx=(8, 11)), NerToken(word='徐國勇', ner='PERSON', idx=(28, 31)), NerToken(word='今天', ner='DATE', idx=(31, 33)), NerToken(word='國防部', ner='ORG', idx=(47, 50)), NerToken(word='立法院內政委會', ner='ORG', idx=(86, 93)), NerToken(word='今天', ner='DATE', idx=(93, 95)), NerToken(word='徐國勇', ner='PERSON', idx=(96, 99)), NerToken(word='民進黨', ner='ORG', idx=(112, 115)), NerToken(word='王美惠', ner='PERSON', idx=(117, 120)), NerToken(word='4個月', ner='DATE', idx=(135, 138)), NerToken(word='一年', ner='DATE', idx=(148, 150)), NerToken(word='徐國勇', ner='PERSON', idx=(151, 154)), NerToken(word='國防部', ner='ORG', idx=(171, 174)), NerToken(word='徐國勇', ner='PERSON', idx=(180, 183)), NerToken(word='8個月', ner='DATE', idx=(210, 213)), NerToken(word='一年', ner='DATE', idx=(276, 278)), NerToken(word='幾個月', ner='DATE', idx=(279, 282)), NerToken(word='王美惠', ner='PERSON', idx=(294, 297)), NerToken(word='俄烏戰爭', ner='EVENT', idx=(300, 304)), NerToken(word='烏克蘭', ner='GPE', idx=(304, 307)), NerToken(word='一天', ner='DATE', idx=(349, 351)), NerToken(word='台灣', ner='GPE', idx=(353, 355)), NerToken(word='徐國勇', ner='PERSON', idx=(367, 370)), NerToken(word='內政部', ner='ORG', idx=(384, 387)), NerToken(word='王美惠', ner='PERSON', idx=(409, 412)), NerToken(word='徐國勇', ner='PERSON', idx=(442, 445))]"]

# %%
news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
allowedNE=['PERSON']
news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']
def ne_word_frequency( a_news_ne ):
    filtered_words =[]
    for ner,word in a_news_ne:
        if (len(word) >= 2) & (ner in allowedNE):
            filtered_words.append(word)
    counter = Counter( filtered_words )
    return counter.most_common( 20 )

# NerToken(word='烏克蘭', ner='GPE', idx=(4, 7))  # call function NerToken with three parameters: word, ner, and idx
def NerToken(word, ner, idx):
    # print(ner,word)
    return ner,word

# %%
    # Get the latest date in the database
latest_date = NewsData.objects.aggregate(max_date=Max('date'))['max_date']

# Calculate start date
start_date = latest_date - timedelta(weeks=4)  # 4 weeks ago

# %%
top_cate_ner_words={}
words_all=[]
for category in news_categories:
    entities_list=list(NewsData.objects.filter(category=category).filter(date__gte=start_date, date__lte=latest_date).values_list('entities', flat=True))
    words_group = []
    for entities in entities_list:
        if entities:
            words_group += eval(entities)

    words_all += words_group

    # Get top words by calling ne_word_frequency() function
    topwords = ne_word_frequency( words_group )
    top_cate_ner_words[category] = topwords

# %%
topwords_all = ne_word_frequency(words_all)
top_cate_ner_words['全部'] = topwords_all

# %%
top_cate_ner_words
# Out:
# {'政治': [('黃重凱', 24),
#   ('柳惠千', 13),
#   ('喬建中', 12),
#   ('徐國勇', 11),
#   ('季欽', 8),
#   ('許舒博', 7),
#   ('游錫堃', 6),
#   ('侯富議', 6),
#   ('蘇貞昌', 5),
#   ('吳釗燮', 4),
#   ('許佑格', 4),
#   ('范惠君', 4),
#   ('歐布萊恩', 4),
#   ('陳其邁', 3),
#   ('柯文哲', 3),
#   ('陳智菡', 3),
#   ('黃鼎翔', 3),
#   ('王同義', 3),
#   ('王美惠', 3),
#   ('許邁德', 2)],
#  '科技': [('林柏亨', 6),
#   ('吳偉仁', 5),
#   ('包淳偉', 4),
#   ('黃晨瑋', 4),
#   ('廖俊智', 4),
#   ('波博', 3),
#   ('黃文山', 3),
#   ('艾偉', 3),
#   ('王金燦', 2),
#   ('庫克', 2),
#   ('曾信超', 2),
#   ('波皮斯庫', 2),
#   ('王兆璋', 1),
#   ('希塔拉姆', 1),
#   ('吳宗信', 1),
#   ('葉均蔚', 1),
#   ('楊勇', 1),
#   ('陳信安', 1),
#   ('Tim哥', 1),
#   ('夏哈', 1)],
#  '運動': [('林昀儒', 24),
#   ('鄭怡靜', 24),
#   ('莊智淵', 17),
#   ('陳將双', 12),
#   ('潘武雄', 10),
#   ('陳建安', 8),
#   ('布雷迪', 7),
#   ('布魯娜', 6),
#   ('賈奈特', 6),
#   ('艾倫', 6),
#   ('塞爾蒂克', 5),
#   ('李恩芯', 5),
#   ('王志庭', 4),
#   ('施冠宇', 4),
#   ('加奇尼', 4),
#   ('樂天', 3),
#   ('安宰賢', 3),
#   ('巴特瑞', 3),
#   ('梁家榮', 3),
#   ('黃子鵬', 3)],
#  '證卷': [('林耕億', 3), ('葉獻文', 2), ('李昌鴻', 2), ('黃水可', 1)],
#  '產經': [('陳耀祥', 17),
#   ('朱澤民', 9),
#   ('曾博昇', 6),
#   ('杜書全', 5),
#   ('蘇松輝', 4),
#   ('趙正宇', 3),
#   ('林崇燾', 3),
#   ('童振源', 3),
#   ('郭幸容', 2),
#   ('林德福', 2),
#   ('吳秉叡', 2),
#   ('李昆澤', 2),
#   ('丁予嘉', 1),
#   ('魏啟林', 1),
#   ('佛里奇', 1),
#   ('史屈特', 1),
#   ('Susannah Streeter）', 1),
#   ('林楚茵', 1),
#   ('許智傑', 1),
#   ('林俊憲', 1)],
#  '娛樂': [('唐川', 20),
#   ('歸亞蕾', 18),
#   ('炎亞綸', 11),
#   ('威廉赫特', 10),
#   ('莊凱勛', 8),
#   ('楊藜', 8),
#   ('林暉閔', 7),
#   ('納豆', 7),
#   ('黃新皓', 6),
#   ('珍康萍', 6),
#   ('曹格', 6),
#   ('侯友宜', 5),
#   ('黃子佼', 5),
#   ('百白', 4),
#   ('孟耿如', 4),
#   ('吳慷仁', 4),
#   ('林心如', 4),
#   ('郭宇宸', 3),
#   ('茶金', 3),
#   ('温昇豪', 3)],
#  '生活': [('陳時中', 13),
#   ('彭佳偉', 13),
#   ('黃恩鴻', 5),
#   ('李宗宏', 3),
#   ('江文全', 2),
#   ('邱基旭', 2),
#   ('蔡佩君', 2),
#   ('王力宏', 1),
#   ('王惠美', 1),
#   ('柯文哲', 1)],
#  '國際': [('蘇利文', 5),
#   ('楊潔篪', 4),
#   ('阿布拉莫維奇', 3),
#   ('蒲亭', 3),
#   ('米佐塔基斯', 3),
#   ('羅傑斯', 3),
#   ('波多利雅科', 3),
#   ('切爾西', 2),
#   ('潘恩', 2),
#   ('拉夫羅夫', 2),
#   ('阿布杜拉希安', 2),
#   ('哈蒂柏札德', 2),
#   ('奧德洛', 2),
#   ('霍恩', 2),
#   ('蕭茲', 2),
#   ('布魯塞爾', 1),
#   ('Marise Payne）', 1),
#   ('米勒', 1),
#   ('Alexey Miller）', 1),
#   ('穆罕穆德', 1)],
#  '社會': [('戴寧', 8),
#   ('孫道存', 7),
#   ('鄭文燦', 6),
#   ('孫芸芸', 4),
#   ('孫瑩瑩', 3),
#   ('孫智宏', 3),
#   ('張女', 2),
#   ('陳澤嘉', 2),
#   ('吳逸萍', 2),
#   ('莊英壽', 2),
#   ('李作宏', 2),
#   ('馬男', 1),
#   ('洪裕翔', 1),
#   ('何念慈育', 1),
#   ('廖偉志', 1),
#   ('廖鎮漢', 1),
#   ('王國材', 1),
#   ('蘇男', 1),
#   ('劉育麟', 1),
#   ('陳依芳', 1)],
#  '文化': [('吳密察', 15),
#   ('平珩', 10),
#   ('吳蠻', 7),
#   ('潘孟安', 6),
#   ('吳思瑤', 5),
#   ('楊書涵', 5),
#   ('李其叡', 5),
#   ('張徐展', 5),
#   ('蔡采崴', 4),
#   ('陳悅宜', 3),
#   ('孫翠鳳', 3),
#   ('朱天文', 3),
#   ('顏伯駿', 3),
#   ('鄭志偉', 3),
#   ('朱安麗', 3),
#   ('柳美', 3),
#   ('大衛．胡斯', 3),
#   ('李安', 2),
#   ('譚盾', 2),
#   ('阿儒瓦苡．篙瑪竿', 2)],
#  '兩岸': [('薛達', 6),
#   ('林鄭月娥', 5),
#   ('劉兆佳', 5),
#   ('雷正龍', 3),
#   ('趙立堅', 3),
#   ('李希', 3),
#   ('希魯阿諾夫', 3),
#   ('王晟', 3),
#   ('布吉敏', 2),
#   ('蒲亭', 2),
#   ('余永定', 2),
#   ('張文宏', 2),
#   ('林柏偉', 1),
#   ('林伯偉', 1),
#   ('黃守應', 1),
#   ('王長青', 1),
#   ('崔靜麟', 1),
#   ('張竹君', 1),
#   ('梁萬年', 1),
#   ('高拔陞', 1)],
#  '全部': [('黃重凱', 24),
#   ('林昀儒', 24),
#   ('鄭怡靜', 24),
#   ('唐川', 20),
#   ('歸亞蕾', 18),
#   ('莊智淵', 17),
#   ('陳耀祥', 17),
#   ('吳密察', 15),
#   ('柳惠千', 13),
#   ('陳時中', 13),
#   ('彭佳偉', 13),
#   ('喬建中', 12),
#   ('陳將双', 12),
#   ('徐國勇', 11),
#   ('炎亞綸', 11),
#   ('潘武雄', 10),
#   ('威廉赫特', 10),
#   ('平珩', 10),
#   ('朱澤民', 9),
#   ('季欽', 8)]}

# %% [markdown]
# ## Save or update top person table

# %%
# save it to db
# save it to db
for category, top_ners in top_cate_ner_words.items():
    # Convert the list of tuples to string representation for storage
    top_keys_str = str(top_ners)
    
    # Check if an entry for this category already exists
    try:
        # Update existing record
        obj = TopPerson.objects.get(category=category)
        obj.top_keys = top_keys_str
        obj.save()
    except TopPerson.DoesNotExist:
        # Create new record
        TopPerson.objects.create(
            category=category,
            top_keys=top_keys_str
        )
