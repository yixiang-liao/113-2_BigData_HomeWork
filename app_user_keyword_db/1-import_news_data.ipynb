# %%
import os
import sys
import pandas as pd
import argparse
from datetime import datetime
import pathlib

# # Setup Django environment
# # Alternative 1: Use absolute path construction
# current_dir = os.path.abspath('')
# parent_dir = os.path.dirname(current_dir)
# sys.path.insert(0, parent_dir)

# # Alternative 2: Use pathlib for more modern path handling
# parent_path = pathlib.Path().absolute().parent
# sys.path.insert(0, str(parent_path))

# 新增：將上一層目錄加入 sys.path
parent_path = pathlib.Path().absolute().parent
sys.path.insert(0, str(parent_path))

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'website_configs.settings')
import django
django.setup()
# 重要：設定環境變數以允許在 Jupyter 的異步環境中執行同步操作
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Now we can import Django models
from app_user_keyword_db.models import NewsData

# %%
# Read CSV file
csv_file_path = '../app_user_keyword/dataset/cna_news_200_preprocessed.csv'
# csv_file_path = '../app_user_keyword/dataset/cna_news_preprocessed_12weeks.csv'
df = pd.read_csv(csv_file_path, sep='|')

# Process each row and create a NewsData object
for idx, row in df.iterrows():
    try:
        # Create or update NewsData object
        # This method tries to fetch an object with the given kwargs, 
        # and if it exists, updates the fields. If it doesn't exist, creates a new one.

        news_data, created = NewsData.objects.update_or_create(
            # Fields to look up the object查詢使用的欄位
            # 這些欄位的組合必須是唯一的，否則會導致錯誤
            # 這裡假設 item_id 是唯一的識別碼 通常是使用主鍵或唯一索引
            item_id=row['item_id'],
            # Fields to update or create with
            # 這些欄位是要更新或創建的欄位
            defaults={
                'date': datetime.strptime(row['date'], '%Y-%m-%d').date(),# Convert date string to datetime object
                'category': row['category'],
                'title': row['title'],
                'content': row['content'],
                'sentiment': row['sentiment'],
                #'summary': row['summary'],
                'top_key_freq': row['top_key_freq'],
                'tokens': row['tokens'],
                'tokens_v2': row['tokens_v2'],
                'entities': row['entities'],
                'token_pos': row['token_pos'],
                'link': row['link'],
                'photo_link': row['photo_link'] if row['photo_link'] != "" and not pd.isna(row['photo_link']) else None,
            }
        )
        if created:
            print(f"Created new NewsData object with item_id: {row['item_id']}")
        else:
            print(f"Updated existing NewsData object with item_id: {row['item_id']}")
    except Exception as e:
        print(f"Error at row {idx}: {e}")
        print(row)
# photo_link 欄位的值可能為以下幾種情況：
# 實際有值的 URL 字串
# 空字串 ("")
# Pandas NaN 值（當 CSV 檔案中該欄位為空時）
# None 值
# Out:
# Updated existing NewsData object with item_id: aipl_20220314_1
# Updated existing NewsData object with item_id: aipl_20220314_2
# Updated existing NewsData object with item_id: aipl_20220314_3
# Updated existing NewsData object with item_id: aipl_20220314_4
# Updated existing NewsData object with item_id: aipl_20220314_5
# Updated existing NewsData object with item_id: aipl_20220314_6
# Updated existing NewsData object with item_id: aipl_20220314_7
# Updated existing NewsData object with item_id: aipl_20220314_8
# Updated existing NewsData object with item_id: aipl_20220314_9
# Updated existing NewsData object with item_id: aipl_20220314_10
# Updated existing NewsData object with item_id: aipl_20220314_11
# Updated existing NewsData object with item_id: aipl_20220314_12
# Updated existing NewsData object with item_id: aipl_20220314_13
# Updated existing NewsData object with item_id: aipl_20220314_14
# Updated existing NewsData object with item_id: aipl_20220314_15
# Updated existing NewsData object with item_id: aipl_20220314_16
# Updated existing NewsData object with item_id: aipl_20220314_17
# Updated existing NewsData object with item_id: aipl_20220314_18
# Updated existing NewsData object with item_id: aipl_20220314_19
# Updated existing NewsData object with item_id: aipl_20220314_20
# Updated existing NewsData object with item_id: ait_20220314_1
# Updated existing NewsData object with item_id: ait_20220314_2
# Updated existing NewsData object with item_id: ait_20220311_3
# Updated existing NewsData object with item_id: ait_20220311_4
# Updated existing NewsData object with item_id: ait_20220310_5
# Updated existing NewsData object with item_id: ait_20220310_6
# Updated existing NewsData object with item_id: ait_20220309_7
# Updated existing NewsData object with item_id: ait_20220309_8
# Updated existing NewsData object with item_id: ait_20220309_9
# Updated existing NewsData object with item_id: ait_20220309_10
# Updated existing NewsData object with item_id: ait_20220309_11
# Updated existing NewsData object with item_id: ait_20220309_12
# Updated existing NewsData object with item_id: ait_20220309_13
# Updated existing NewsData object with item_id: ait_20220309_14
# Updated existing NewsData object with item_id: ait_20220308_15
# Updated existing NewsData object with item_id: ait_20220308_16
# Updated existing NewsData object with item_id: ait_20220308_17
# Updated existing NewsData object with item_id: ait_20220307_18
# Updated existing NewsData object with item_id: ait_20220307_19
# Updated existing NewsData object with item_id: ait_20220303_20
# Updated existing NewsData object with item_id: aspt_20220314_1
# Updated existing NewsData object with item_id: aspt_20220314_2
# Updated existing NewsData object with item_id: aspt_20220314_3
# Updated existing NewsData object with item_id: aspt_20220314_4
# Updated existing NewsData object with item_id: aspt_20220314_5
# Updated existing NewsData object with item_id: aspt_20220314_6
# Updated existing NewsData object with item_id: aspt_20220314_7
# Updated existing NewsData object with item_id: aspt_20220314_8
# Updated existing NewsData object with item_id: aspt_20220314_9
# Updated existing NewsData object with item_id: aspt_20220314_10
# Updated existing NewsData object with item_id: aspt_20220314_11
# Updated existing NewsData object with item_id: aspt_20220314_12
# Updated existing NewsData object with item_id: aspt_20220314_13
# Updated existing NewsData object with item_id: aspt_20220314_14
# Updated existing NewsData object with item_id: aspt_20220314_15
# Updated existing NewsData object with item_id: aspt_20220314_16
# Updated existing NewsData object with item_id: aspt_20220313_17
# Updated existing NewsData object with item_id: aspt_20220313_18
# Updated existing NewsData object with item_id: aspt_20220313_19
# Updated existing NewsData object with item_id: aspt_20220313_20
# Updated existing NewsData object with item_id: asc_20220314_1
# Updated existing NewsData object with item_id: asc_20220314_2
# Updated existing NewsData object with item_id: asc_20220314_3
# Updated existing NewsData object with item_id: asc_20220314_4
# Updated existing NewsData object with item_id: asc_20220314_5
# Updated existing NewsData object with item_id: asc_20220314_6
# Updated existing NewsData object with item_id: asc_20220314_7
# Updated existing NewsData object with item_id: asc_20220314_8
# Updated existing NewsData object with item_id: asc_20220314_9
# Updated existing NewsData object with item_id: asc_20220314_10
# Updated existing NewsData object with item_id: asc_20220314_11
# Updated existing NewsData object with item_id: asc_20220314_12
# Updated existing NewsData object with item_id: asc_20220314_13
# Updated existing NewsData object with item_id: asc_20220314_14
# Updated existing NewsData object with item_id: asc_20220314_15
# Updated existing NewsData object with item_id: asc_20220314_16
# Updated existing NewsData object with item_id: asc_20220314_17
# Updated existing NewsData object with item_id: asc_20220314_18
# Updated existing NewsData object with item_id: asc_20220314_19
# Updated existing NewsData object with item_id: asc_20220314_20
# Updated existing NewsData object with item_id: aie_20220314_1
# Updated existing NewsData object with item_id: aie_20220314_2
# Updated existing NewsData object with item_id: aie_20220314_3
# Updated existing NewsData object with item_id: aie_20220314_4
# Updated existing NewsData object with item_id: aie_20220314_5
# Updated existing NewsData object with item_id: aie_20220314_6
# Updated existing NewsData object with item_id: aie_20220314_7
# Updated existing NewsData object with item_id: aie_20220314_8
# Updated existing NewsData object with item_id: aie_20220314_9
# Updated existing NewsData object with item_id: aie_20220314_10
# Updated existing NewsData object with item_id: aie_20220314_11
# Updated existing NewsData object with item_id: aie_20220314_12
# Updated existing NewsData object with item_id: aie_20220314_13
# Updated existing NewsData object with item_id: aie_20220314_14
# Updated existing NewsData object with item_id: aie_20220314_15
# Updated existing NewsData object with item_id: aie_20220314_16
# Updated existing NewsData object with item_id: aie_20220314_17
# Updated existing NewsData object with item_id: aie_20220314_18
# Updated existing NewsData object with item_id: aie_20220314_19
# Updated existing NewsData object with item_id: aie_20220314_20
# Updated existing NewsData object with item_id: amov_20220314_1
# Updated existing NewsData object with item_id: amov_20220314_2
# Updated existing NewsData object with item_id: amov_20220314_3
# Updated existing NewsData object with item_id: amov_20220314_4
# Updated existing NewsData object with item_id: amov_20220314_5
# Updated existing NewsData object with item_id: amov_20220314_6
# Updated existing NewsData object with item_id: amov_20220314_7
# Updated existing NewsData object with item_id: amov_20220314_8
# Updated existing NewsData object with item_id: amov_20220314_9
# Updated existing NewsData object with item_id: amov_20220314_10
# Updated existing NewsData object with item_id: amov_20220314_11
# Updated existing NewsData object with item_id: amov_20220313_12
# Updated existing NewsData object with item_id: amov_20220313_13
# Updated existing NewsData object with item_id: amov_20220313_14
# Updated existing NewsData object with item_id: amov_20220312_15
# Updated existing NewsData object with item_id: amov_20220312_16
# Updated existing NewsData object with item_id: amov_20220312_17
# Updated existing NewsData object with item_id: amov_20220312_18
# Updated existing NewsData object with item_id: amov_20220311_19
# Updated existing NewsData object with item_id: amov_20220311_20
# Updated existing NewsData object with item_id: ahel_20220314_1
# Updated existing NewsData object with item_id: ahel_20220314_2
# Updated existing NewsData object with item_id: ahel_20220314_3
# Updated existing NewsData object with item_id: ahel_20220314_4
# Updated existing NewsData object with item_id: ahel_20220314_5
# Updated existing NewsData object with item_id: ahel_20220314_6
# Updated existing NewsData object with item_id: ahel_20220314_7
# Updated existing NewsData object with item_id: ahel_20220314_8
# Updated existing NewsData object with item_id: ahel_20220314_9
# Updated existing NewsData object with item_id: ahel_20220314_10
# Updated existing NewsData object with item_id: ahel_20220314_11
# Updated existing NewsData object with item_id: ahel_20220314_12
# Updated existing NewsData object with item_id: ahel_20220314_13
# Updated existing NewsData object with item_id: ahel_20220314_14
# Updated existing NewsData object with item_id: ahel_20220314_15
# Updated existing NewsData object with item_id: ahel_20220314_16
# Updated existing NewsData object with item_id: ahel_20220314_17
# Updated existing NewsData object with item_id: ahel_20220314_18
# Updated existing NewsData object with item_id: ahel_20220314_19
# Updated existing NewsData object with item_id: ahel_20220314_20
# Updated existing NewsData object with item_id: aopl_20220314_1
# Updated existing NewsData object with item_id: aopl_20220314_2
# Updated existing NewsData object with item_id: aopl_20220314_3
# Updated existing NewsData object with item_id: aopl_20220314_4
# Updated existing NewsData object with item_id: aopl_20220314_5
# Updated existing NewsData object with item_id: aopl_20220314_6
# Updated existing NewsData object with item_id: aopl_20220314_7
# Updated existing NewsData object with item_id: aopl_20220314_8
# Updated existing NewsData object with item_id: aopl_20220314_9
# Updated existing NewsData object with item_id: aopl_20220314_10
# Updated existing NewsData object with item_id: aopl_20220314_11
# Updated existing NewsData object with item_id: aopl_20220314_12
# Updated existing NewsData object with item_id: aopl_20220314_13
# Updated existing NewsData object with item_id: asoc_20220314_1
# Updated existing NewsData object with item_id: asoc_20220314_2
# Updated existing NewsData object with item_id: asoc_20220314_3
# Updated existing NewsData object with item_id: asoc_20220314_4
# Updated existing NewsData object with item_id: asoc_20220314_5
# Updated existing NewsData object with item_id: asoc_20220314_6
# Updated existing NewsData object with item_id: asoc_20220314_7
# Updated existing NewsData object with item_id: asoc_20220314_8
# Updated existing NewsData object with item_id: asoc_20220314_9
# Updated existing NewsData object with item_id: asoc_20220314_10
# Updated existing NewsData object with item_id: asoc_20220314_11
# Updated existing NewsData object with item_id: asoc_20220314_12
# Updated existing NewsData object with item_id: asoc_20220314_13
# Updated existing NewsData object with item_id: asoc_20220314_14
# Updated existing NewsData object with item_id: asoc_20220314_15
# Updated existing NewsData object with item_id: asoc_20220314_16
# Updated existing NewsData object with item_id: asoc_20220314_17
# Updated existing NewsData object with item_id: asoc_20220314_18
# Updated existing NewsData object with item_id: asoc_20220314_19
# Updated existing NewsData object with item_id: asoc_20220314_20
# Updated existing NewsData object with item_id: acul_20220314_1
# Updated existing NewsData object with item_id: acul_20220314_2
# Updated existing NewsData object with item_id: acul_20220314_3
# Updated existing NewsData object with item_id: acul_20220314_4
# Updated existing NewsData object with item_id: acul_20220314_5
# Updated existing NewsData object with item_id: acul_20220314_6
# Updated existing NewsData object with item_id: acul_20220314_7
# Updated existing NewsData object with item_id: acul_20220314_8
# Updated existing NewsData object with item_id: acul_20220314_9
# Updated existing NewsData object with item_id: acul_20220314_10
# Updated existing NewsData object with item_id: acul_20220314_11
# Updated existing NewsData object with item_id: acul_20220314_12
# Updated existing NewsData object with item_id: acul_20220314_13
# Updated existing NewsData object with item_id: acul_20220314_14
# Updated existing NewsData object with item_id: acul_20220313_15
# Updated existing NewsData object with item_id: acul_20220313_16
# Updated existing NewsData object with item_id: acul_20220313_17
# Updated existing NewsData object with item_id: acul_20220313_18
# Updated existing NewsData object with item_id: acul_20220313_19
# Updated existing NewsData object with item_id: acul_20220313_20
# Updated existing NewsData object with item_id: acn_20220314_1
# Updated existing NewsData object with item_id: acn_20220314_2
# Updated existing NewsData object with item_id: acn_20220314_3
# Updated existing NewsData object with item_id: acn_20220314_4
# Updated existing NewsData object with item_id: acn_20220314_5
# Updated existing NewsData object with item_id: acn_20220314_6
# Updated existing NewsData object with item_id: acn_20220314_7
# Updated existing NewsData object with item_id: acn_20220314_8
# Updated existing NewsData object with item_id: acn_20220314_9
# Updated existing NewsData object with item_id: acn_20220314_10
# Updated existing NewsData object with item_id: acn_20220314_11
# Updated existing NewsData object with item_id: acn_20220314_12
# Updated existing NewsData object with item_id: acn_20220314_13
# Updated existing NewsData object with item_id: acn_20220314_14
# Updated existing NewsData object with item_id: acn_20220314_15
# Updated existing NewsData object with item_id: acn_20220314_16
# Updated existing NewsData object with item_id: acn_20220314_17
# Updated existing NewsData object with item_id: acn_20220314_18
# Updated existing NewsData object with item_id: acn_20220314_19
# Updated existing NewsData object with item_id: acn_20220313_20

# %%
created
# Out:
# False
